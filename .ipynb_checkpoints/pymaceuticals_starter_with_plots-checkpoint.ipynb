# %%
import this
import numpy as np
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %% [markdown]
# # Pymaceuticals Inc.
# ---
#
# ### Analysis
# * Overall, it is clear that Capomulin is a viable drug regimen to reduce tumor growth.
# * Capomulin had the most number of mice complete the study, with the exception of Remicane, all other regimens observed a number of mice deaths across the duration of the study.
# * There is a strong correlation between mouse weight and tumor volume, indicating that mouse weight may be contributing to the effectiveness of any drug regimen.
# * There was one potential outlier within the Infubinol regimen. While most mice showed tumor volume increase, there was one mouse that had a reduction in tumor growth in the study.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# %%
# Combine the data into a single dataset
df = pd.merge(study_results, mouse_metadata, how='left', left_on='Mouse ID', right_on='Mouse ID')

# %%
# Display the data table for preview
df.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0                45.0                 0    Capomulin
# 1     f932          0                45.0                 0     Ketapril
# 2     g107          0                45.0                 0     Ketapril
# 3     a457          0                45.0                 0     Ketapril
# 4     c819          0                45.0                 0     Ketapril
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1    Male          15          29
# 2  Female           2          29
# 3  Female          11          30
# 4    Male          21          25

# %%
# Checking the number of mice.
len(df['Mouse ID'].value_counts())
# Out:
# 249

# %%
# Getting the duplicate mice by ID number thatcounts up for Mouse ID and Timepoint. 
mouse_groupby_4_dedup = df.groupby(['Mouse ID','Timepoint']).Timepoint.agg('count')
mouse_groupby_4_dedup = pd.DataFrame(mouse_groupby_4_dedup)
df_Mouse_by_Timepoint = mouse_groupby_4_dedup.rename(columns= {'Timepoint': 'Count'})
df_Mouse_by_Timepoint
# Out:
#                     Count
# Mouse ID Timepoint
# a203     0              1
#          5              1
#          10             1
#          15             1
#          20             1
# ...                   ...
# z969     25             1
#          30             1
#          35             1
#          40             1
#          45             1
#
# [1888 rows x 1 columns]

# %%
# Optional: Get all the data for the duplicate mouse ID. 
duplicate_mouse_id = df_Mouse_by_Timepoint.loc[df_Mouse_by_Timepoint['Count'] != 1].index[1][0]
df_duplicate = df.loc[df['Mouse ID'] == duplicate_mouse_id,:]
df_duplicate
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 107      g989          0           45.000000                 0     Propriva
# 137      g989          0           45.000000                 0     Propriva
# 329      g989          5           48.786801                 0     Propriva
# 360      g989          5           47.570392                 0     Propriva
# 620      g989         10           51.745156                 0     Propriva
# 681      g989         10           49.880528                 0     Propriva
# 815      g989         15           51.325852                 1     Propriva
# 869      g989         15           53.442020                 0     Propriva
# 950      g989         20           55.326122                 1     Propriva
# 1111     g989         20           54.657650                 1     Propriva
# 1195     g989         25           56.045564                 1     Propriva
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
df_dedup = df.loc[df['Mouse ID'] != duplicate_mouse_id,:]
df_dedup = pd.DataFrame(df_dedup)
df_dedup
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0        b128          0           45.000000                 0    Capomulin
# 1        f932          0           45.000000                 0     Ketapril
# 2        g107          0           45.000000                 0     Ketapril
# 3        a457          0           45.000000                 0     Ketapril
# 4        c819          0           45.000000                 0     Ketapril
# ...       ...        ...                 ...               ...          ...
# 1888     r944         45           41.581521                 2    Capomulin
# 1889     u364         45           31.023923                 3    Capomulin
# 1890     p438         45           61.433892                 1     Ceftamin
# 1891     x773         45           58.634971                 4      Placebo
# 1892     b879         45           72.555239                 2     Stelasyn
#
#          Sex  Age_months  Weight (g)
# ...

# %%
# Checking the number of mice in the clean DataFrame.
len(df_dedup['Mouse ID'].value_counts())
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary dataframe.
df_orig = df 
df = pd.DataFrame(df_dedup)
df_summary = df.groupby(['Drug Regimen'])['Tumor Volume (mm3)'].agg(['mean','median','var','std', 'sem','size'])
df_summary = pd.DataFrame(df_summary)
df_summary.columns = ['Mean Tumor Volume','Median Tumor Volume','Tumor Volume Variance','Tumor Volume Std. Dev.','Tumor Volume Std. Err.','Regimen Sample Size']
df_summary
# Out:
#               Mean Tumor Volume  Median Tumor Volume  Tumor Volume Variance  \
# Drug Regimen
# Capomulin             40.675741            41.557809              24.947764
# Ceftamin              52.591172            51.776157              39.290177
# Infubinol             52.884795            51.820584              43.128684
# Ketapril              55.235638            53.698743              68.553577
# Naftisol              54.331565            52.509285              66.173479
# Placebo               54.033581            52.288934              61.168083
# Propriva              52.320930            50.446266              43.852013
# Ramicane              40.216745            40.673236              23.486704
# Stelasyn              54.233149            52.431737              59.450562
# Zoniferol             53.236507            51.818479              48.533355
#
#               Tumor Volume Std. Dev.  Tumor Volume Std. Err.  \
# Drug Regimen
# ...

# %%
## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of measurements taken on each drug regimen using pandas.
ax = df_summary['Regimen Sample Size'].plot.bar(y='Regimen Sample Size')
ax.set_ylabel("Regimen Sample Size");

# %%
#Using PLT
fig = plt.figure(figsize = (10, 5))
plt.bar(df_summary.index, df_summary['Regimen Sample Size'], color ='orange', width = 0.4)
plt.xlabel('Drug Regimen')
plt.ylabel('total number of measurements');

# %%
# Generate a bar plot showing the total number of measurements taken on each drug regimen using using pyplot.

# %%
df_sex = df_dedup['Sex'].value_counts()
df_sex = pd.DataFrame(df_sex)

# %%
ax_sex = df_sex.plot.pie(y='Sex',legend=False,autopct='%1.f%%')

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas

# %%
plt.pie(df_sex['Sex'],labels=['Male','Female'],autopct='%1.f%%')
plt.ylabel('Sex');

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
regimen = {'Capomulin' : [], 'Ramicane': [], 'Infubinol': [],  'Ceftamin': []}
ogkeys = list(regimen.keys())
mice = df['Mouse ID'].value_counts()
df2 = pd.DataFrame(mice).reset_index()
df2.columns = ['Mouse ID','Count']
df_dedup2 = df_dedup.set_index('Mouse ID')
max_timepoint = []
id_mouse = []
size_tumor = []
for mice in df_dedup2.index.unique():
    max_timepoint.append(df_dedup2.loc[mice,'Timepoint'].max())
    id_mouse.append(mice)
    
# Start by getting the last (greatest) timepoint for each mouse
a = {'id_mouse': id_mouse, 'max_timepoint': max_timepoint}
tumor_df = pd.DataFrame(a)
# Merge this group df with the original dataframe to get the tumor volume at the last timepoint
new_tumor_df = pd.merge(tumor_df, df_dedup,  how='left', left_on=['id_mouse', 'max_timepoint'], right_on =['Mouse ID', 'Timepoint'])
#da = tumor_df['id_mouse'] + str(tumor_df['max_timepoint'])
#tumor_df['unique_id'] = da
#da
quartile_df = new_tumor_df.drop(columns=['Mouse ID', 'Timepoint'] )
quartile_df
# Out:
#     id_mouse  max_timepoint  Tumor Volume (mm3)  Metastatic Sites  \
# 0       b128             45           38.982878                 2
# 1       f932              0           45.000000                 0
# 2       g107             35           71.905117                 0
# 3       a457             10           49.783419                 0
# 4       c819             40           62.175705                 1
# ..       ...            ...                 ...               ...
# 243     t565             45           34.455298                 0
# 244     i557             45           47.685963                 1
# 245     m957             45           33.329098                 1
# 246     f966             20           30.485985                 0
# 247     m601             45           28.430964                 1
#
#     Drug Regimen     Sex  Age_months  Weight (g)
# 0      Capomulin  Female           9          22
# 1       Ketapril    Male          15          29
# ...

# %%
#listreg = list(regimen)
for key in list(regimen.keys()):
    i = str(key)
    i = quartile_df.loc[quartile_df['Drug Regimen'] == key,'Tumor Volume (mm3)'].tolist()
    regimen[key] = i

# %%
for key, value in list(regimen.items()):
    j = pd.Series(value, dtype='float64')
    quartiles = j.quantile([.25,.5,.75])
    lowerq = quartiles[.25]
    upperq = quartiles[.75]
    iqr = upperq-lowerq
    lower_bound = lowerq - (1.5*iqr)
    upper_bound = upperq + (1.5*iqr)
    regimen['upperq_%s' % key] = upperq
    regimen['lowerq_%s' % key] = lowerq
    regimen['iqr_%s' % key] = iqr
    regimen['lbound_%s' % key] = lower_bound
    regimen['ubound_%s' % key] = upper_bound

# %%
for key, v in list(regimen.items()):
    outlier = []
    if key in ogkeys:
        for m in v:
            if m < regimen['lbound_%s' % key] or m > regimen['ubound_%s' % key]:
                outlier.append(m)
        regimen['outliers_%s' % key] = outlier

# %%
# See the dict to find all values Quartiles, IQR and Outliers
regimen
# Out:
# {'Capomulin': [38.98287774,
#   38.75326548,
#   32.37735684,
#   23.34359787,
#   38.93963263,
#   28.48403281,
#   41.48300765,
#   40.72857787,
#   46.53920617,
#   31.02392294,
#   38.125164399999996,
#   40.65812366,
#   36.04104736,
#   37.31184577,
#   41.58152074,
#   31.896238399999998,
#   40.1592203,
#   37.07402422,
#   38.84687569,
#   39.95234669,
#   34.45529799,
#   47.68596303,
#   33.32909778,
#   30.48598484,
#   28.43096411],
#  'Ramicane': [38.34200823,
#   36.56165229,
#   31.56046955,
#   38.407618299999996,
#   43.04754260000001,
#   37.31123552,
#   36.13485243,
#   44.18345092,
#   22.05012627,
#   33.39765251,
#   37.22565033,
#   32.97852192,
#   33.56240217,
#   29.12847181,
#   38.81036633,
#   40.66771292,
#   30.56462509,
#   43.16637266,
#   31.09533505,
#   30.27623175,
#   40.65900627,
#   30.63869575,
#   43.41938077,
#   45.22086888,
#   36.37451039],
#  'Infubinol': [36.321345799999996,
#   72.2267309,
#   46.25011212,
#   57.03186187,
# ...

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
# Out:
# The correlation between mouse weight and the average tumor volume is 0.84
